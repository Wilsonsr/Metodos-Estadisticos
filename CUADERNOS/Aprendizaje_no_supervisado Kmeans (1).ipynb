# %% [markdown]
# <center>
#
# # **Aprendizaje no supervisado**
#
# </center>
#
# Aunque la mayoría de las aplicaciones en Machine Learning son basadas en aprendizaje supervisado. Sin embargo, la gran mayoría de los datos disponibles no tienen etiqueta. Es decir, tenemos la entrada $X$ pero no la salida $y$.
#
# <img src='https://www.researchgate.net/publication/329533120/figure/fig1/AS:702267594399761@1544445050584/Supervised-learning-and-unsupervised-learning-Supervised-learning-uses-annotation.png' height=500px>
#
# *El ser humano es capaz de identificar que estos objetos son diferentes, aunque nadie le explique que son!*

# %% [markdown]
# **Niño aprendiendo de manera supervisada**
#
# ![](https://www.myfirstskool.com/resources/ck/images/MFS%20Images/Resources/Our%20Articles/my-first-skool-relationship-building.jpg)
#
# **Niño aprendiendo de manera no supervisada**
#
# ![](https://cf.ltkcdn.net/kids/images/orig/178221-446x384-Little-boy-with-shape-puzzle-TS.jpg)

# %% [markdown]
# ## Etiquetar y etiquetar! El problema del aprendizaje supervisado
#
# Si no tenemos etiquetas, para aplicar aprendizaje supervisado, tendremos dos opciones: utilizar una base de datos etiquetada o etiquetarlo nosotros mismos:
#
# **Clasificación**
#
# <img src='https://docs.microsoft.com/en-us/azure/machine-learning/media/tutorial-labeling/catsndogs.gif' height=500px>
#
#
# **Texto**
#
# <img src='https://miro.medium.com/max/900/1*gSevidhae1D8qwIZpl1z0w.gif' height=500px>

# %% [markdown]
# ## Soluciones
#
# Al respecto, muchas soluciones se han creado para facilitar el trabajo de etiquetado. En [esta página](https://github.com/heartexlabs/awesome-data-labeling) puede ver una lista de herramientas opensource, por ejemplo para el caso de texto [esta](https://github.com/doccano/doccano) es una buena alternativa. También existen empresas que se han dedicado a ofrecer estos servicios como [playment](https://playment.io/gt-studio), [lionbridge](https://lionbridge.ai/solutions/), [labelbox](https://labelbox.com/) o [snorkel](https://www.snorkel.ai/platform), a las cuales [no les ha ido nada mal](https://www.forbes.com/sites/cognitiveworld/2020/02/02/the-human-powered-companies-that-make-ai-work/?sh=1da768f670cc)!
#
# Como se puede dar cuenta, es un negocio muy lucrativo y en crecimiento. Y en la primer línea de aplicaciones, los seres humanos somos muy buenos. Y esto lo han sabido hacer de manera muy creativa, mediante una pequeña recompensa para quien etiquete:
#
# **Etiquetado colaborativo**
#
# *Como [conseguir acceso](https://www.ted.com/talks/luis_von_ahn_massive_scale_online_collaboration?language=es) a nuestra aplicación web favorita*
#
# <img src='https://www.welivesecurity.com/wp-content/uploads/2014/12/CAPTCHA_google.png' height=300px>
#
# *O conseguir seguidores en nuestra red social*
#
# <img src='https://media1.tenor.com/images/1e712136c27d43288d5ac773a2ccd41d/tenor.gif?itemid=7197218'>
#
# Con lo cual se conisgue hacer aplicaciones como [esta](https://youtu.be/wEgn_sDMzoo)
#
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSjKa1Q0L-ZKxnrtPaeG5qmlNxGNf06yrPCgpnTHlIa_sUOV_GsKHqbGNvsPSWBdJ1BCxRJgakBGlpz8NjKJ0GYePCNhMsROTWFk4dMeA&usqp=CAU&ec=45722097'>

# %% [markdown]
# # Tareas comunes del aprendizaje no supervisado
# El aprendizaje supervisado requiere de la intervención humana para conseguir un modelo de pronóstico, pero algunas veces esa intervención no está puesta sobre la mesa. Por tanto, se han desarrollado metodologías  para evitar el uso de las etiquetas y han conseguido resolver las siguientes tareas:
#
# 1. Reducción de la dimensionalidad
# 2. Clustering
# 3. Detección de anomalías
# 4. Estimación de densidad de probabilidad

# %% [markdown]
# ## Clustering
#
# Similar a la clasificación supervisada, cada instancia consigue ser asignada a una categoría. Algunas de sus aplicaciones son:
#
# * Segmentación de clientes
# * Sistemas de recomendación
# * Análisis de datos descriptivo
# * Reducción de dimensionalidad
# * Detección de anomalías
# * Aprendizaje semi-supervisado
# * Motores de búsqueda
# * Segmentación de imágenes
#
# Vamos a trabajar con algunas herramientas de `sklearn`, pero antes debemos importar las librerías que se utilizarán a lo largo de este notebook.

# %% [markdown]
# Objetivos:
# - Definir el agrupamiento en clústeres para las aplicaciones de AA.
# - Preparar datos para el agrupamiento en clústeres
# - Definir la similitud para tu conjunto de datos.
# - Comparar medidas de similitud supervisadas y manuales
# - Usa el algoritmo k-means para agrupar los datos.
# - Evaluar la calidad del resultado del agrupamiento en clústeres

# %% [markdown]
# ## ¿Qué es el agrupamiento en clústeres?
#
#
# Cuando intentes aprender algo, por ejemplo, música, un enfoque podría ser buscar grupos o colecciones significativos. se podría organizar la música por género, mientras que alguién mas  podría organizarla por década.
#
# La manera en que se agrupan los elementos ayudan a comprenderlos como piezas musicales individuales.

# %% [markdown]
# ## ¿Cuáles son los usos del agrupamiento en clústeres?
# El agrupamiento en clústeres tiene innumerables usos en una variedad de industrias. Algunas aplicaciones comunes para el agrupamiento en clústeres son las siguientes:
#
# - segmentación de mercado
# - análisis de redes sociales
# - agrupación de resultados de la búsqueda
# - diagnóstico por imágenes
# - segmentación de imágenes
# - detección de anomalías

# %% [markdown]
# ## Tipos de agrupamiento en clústeres
# Existen varios enfoques para el agrupamiento en clústeres
#
# ### Agrupamiento en clústeres basado en centroides
# Los algoritmos basados en centroides son eficientes, pero sensibles a las condiciones y valores atípicos iniciales.
#
# <img src="https://developers.google.com/static/machine-learning/clustering/images/CentroidBasedClustering.svg?hl=es-419" width="300" height="500">

# %% [markdown]
# ### Agrupamiento en clústeres basado en la densidad
#
# El agrupamiento en clústeres basado en la densidad conecta áreas de alta densidad de ejemplo en clústeres. Esto permite distribuciones arbitrarias, siempre y cuando se puedan conectar áreas densas. Estos algoritmos tienen dificultades con los datos de las distintas densidades y dimensiones. Además, por diseño, estos algoritmos no asignan valores atípicos a los clústeres.
#
# <img src="https://github.com/Wilsonsr/Metodos-Estadisticos/raw/main/BASES/agrupamiento_densidad.png" >

# %% [markdown]
# ## Agrupamiento en clústeres basado en la distribución
# En este enfoque de agrupamiento en clústeres, se supone que los datos están compuestos por distribuciones, como distribuciones gaussianas. En la Figura, el algoritmo basado en distribución agrupa los datos en tres distribuciones gaussianas. A medida que aumenta la distancia desde el centro de distribución, la probabilidad de que un punto pertenezca a la distribución disminuye. Las bandas muestran esa disminución de la probabilidad. Si no conoces el tipo de distribución en tus datos, debes usar un algoritmo diferente.
#
# <img src="https://github.com/Wilsonsr/Metodos-Estadisticos/raw/main/BASES/agrupamiento_distribuci%C3%B3n.png">

# %% [markdown]
# ## Agrupamiento en clústeres jerárquico
#
# El agrupamiento en clústeres jerárquico crea un árbol de clústeres. Adecuado para datos jerárquicos, como las taxonomías.
#
# <img src="https://github.com/Wilsonsr/Metodos-Estadisticos/raw/main/BASES/agrupamiento_jerarquico.png">

# %% [markdown]
# #### Flujo de trabajo del agrupamiento en clústeres
#
#
# Para agrupar datos en clústeres:
#
# - Preparar los datos.
# - Crear una métrica de similitud.
# - Ejecutar el algoritmo de agrupamiento en clústeres.
# - Interpretar los resultados y ajusta la agrupación en clústeres.

# %% [markdown]
# ### Preparar los datos
#
#
#
#
# En el agrupamiento en clústeres, se calcula la similitud entre dos ejemplos mediante la combinación de todos los datos de atributos de esos ejemplos en un valor numérico.
#
# La combinación de datos de atributos requiere que los datos tengan la misma escala.
#
# #### Normalizar datos
#
# Se puedes transformar los datos de varios atributos a la misma escala  normalizando los datos. En particular, la normalización es adecuada para procesar la distribución de datos más común, la distribución gaussiana. En comparación con los cuantiles, la normalización requiere muchos menos datos para calcular. Para normalizar los datos, calcula su puntuación z de la siguiente manera:
#
#
# $$
# x'=\frac{x-\mu}{\sigma}
#
#
#
#
#
#
#
# $$
#
# - $\mu$: media
# - $\sigma $  desviación estándar.
#
# <img src="https://github.com/Wilsonsr/Metodos-Estadisticos/raw/main/BASES/screenshot_73.png">
#
#
#  Aplica la normalización cuando se cumpla alguna de las siguientes condiciones:
#
# - Los datos tienen una distribución gaussiana.
# - El conjunto de datos no tiene datos suficientes para crear cuantiles.

# %% [markdown]
# ### Usar cuantiles
# Las transformaciones de normalización y registro abordan distribuciones de datos específicas. ¿Qué sucede si los datos no cumplen con una distribución gaussiana o de ley? ¿Hay algún enfoque general que se aplique a cualquier distribución de datos?
#
# <img src="https://github.com/Wilsonsr/Metodos-Estadisticos/raw/main/BASES/cauantile_1.png">
#
# **Si se normaliza**
#
# <img src="https://github.com/Wilsonsr/Metodos-Estadisticos/raw/main/BASES/cuantiles_2.png">

# %% [markdown]
# En cambio, dividir los datos en intervalos en los que cada intervalo contenga la misma cantidad de ejemplos. Estos límites de intervalos se denominan cuantiles.
#
# Convertir los datos en cuantiles mediante los siguientes pasos:
#
# 1. decidir la cantidad de intervalos.
# 2. Definir intervalos de modo que cada intervalo tenga la misma cantidad de ejemplos.
# 3. Reemplazar cada ejemplo por el índice del intervalo en el que se encuentra.
# 4. Ajustar los índices al mismo rango que otros datos de atributos mediante el escalamiento de los valores del índice a [0,1].
#
#
# <img src="https://github.com/Wilsonsr/Metodos-Estadisticos/raw/main/BASES/cuantiles_3.png">

# %% [markdown]
# Después de convertir los datos en cuantiles, la similitud entre dos ejemplos es inversamente proporcional a la cantidad de ejemplos entre esos dos ejemplos. O, matemáticamente, donde "x" es cualquier ejemplo en el conjunto de datos:
#
#
# - $\operatorname{sim}(A, B) \approx 1-|\operatorname{prob}[x>A]-\operatorname{prob}[x>B]|$
# - $\operatorname{sim}(A, B) \approx 1-\mid$ quantile $(A)-$ quantile $(B) \mid$
#
#
# Los cuantiles son la mejor opción predeterminada para transformar datos.
#
# - Sin embargo, para crear cuantiles que sean indicadores confiables de la distribución de datos subyacente, se necesitan muchos datos. Como regla general, para crear  cuantiles, debes tener al menos $10n$
#  ejemplos.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <center>
#
# ---
# ## **k-means**
# ---
#
# </center>

# %% [markdown]
# El clustering es el proceso de aprendizaje no supervisado que consiste en dividir los puntos de datos en grupos, de manera que los puntos de datos que pertenecen a los mismos grupos tienen características similares a las de otros puntos de datos del mismo grupo y son diferentes a los puntos de datos que pertenecen a grupos diferentes.
#
# ![](https://miro.medium.com/max/1400/1*YfCS_VFJTF-rVCl3DSY_hg.gif)
#
# El clustering se basa en dos métricas importantes:
#
# - La distancia interclúster y
# - la distancia intraclúster.
#
# En condiciones ideales, para que el clustering funcione bien, la distancia inter-cluster debe ser muy alta y la distancia intra-cluster debe ser muy baja.
#
#
# ![](https://miro.medium.com/max/1400/1*FbPP5TvWtA2yQ14xxsRWvQ.gif)
#
#
# **K-Means**  Este algoritmo toma los puntos de datos y da el conjunto predefinido de clusters.
#
# - `$D=\{x_1,x_2......,x_n\}$ tiene $n$ puntos con $k$ clusters ($S_1,S_2..S_k$) y cada cluster tiene asignado un centroide$( C_1,C_2, C_3..C_k)$. Cada punto del conjunto de datos se asigna al conjunto ($S_i$) en función del centroide más cercano a él. El centroide $(C_i)$ es el punto medio de todos los demás puntos del conjunto de puntos $(S_i)$. Se calcula como se indica a continuación:
#
#
# ## Intuición geométrica de K-Means
#
# ![](https://miro.medium.com/max/1400/1*Vkq654s0AXi-MC3abYcjOw.gif)

# %% [markdown]
# ## **El algoritmo k-means**
# K-means es un algoritmo de clasificación no supervisada (clusterización) que agrupa objetos en k grupos basándose en sus características. El agrupamiento se realiza minimizando la suma de distancias entre cada objeto y el centroide de su grupo o cluster. Se suele usar la distancia cuadrática.
#
# ### El algoritmo consta de tres pasos:
#
# - **Inicialización:** una vez escogido el número de grupos, $k$, se establecen $k$ centroides en el espacio de los datos, por ejemplo, escogiéndolos aleatoriamente.
#
# - **Asignación objetos a los centroides:** cada objeto de los datos es asignado a su centroide más cercano.
#
# - **Actualización centroides:** se actualiza la posición del centroide de cada grupo tomando como nuevo centroide la posición del promedio de los objetos pertenecientes a dicho grupo.
# Se repiten los pasos 2 y 3 hasta que los centroides no se mueven, o se mueven por debajo de una distancia umbral en cada paso.
#
# El algoritmo k-means resuelve un problema de optimización, siendo la función a optimizar (minimizar) la suma de las distancias cuadráticas de cada objeto al centroide de su cluster.
#
# Los objetos se representan con vectores reales de  $d$  dimensiones  $(x_1,x_2,…,x_n)$  y el algoritmo k-means construye  $k$  grupos donde se minimiza la suma de distancias de los objetos, dentro de cada grupo  $S=\{S_1,S_2,…,S_k\}$ , a su centroide.
#
#
# <center>
#
# ### $$\underset{\mathbf{S}}{\mathrm{min}}\; E\left(\boldsymbol{\mu_{i}}\right)=\underset{\mathbf{S}}{\mathrm{min}}\sum_{i=1}^{k}\sum_{\mathbf{x}_{j}\in S_i}\left\Vert \mathbf{x}_{j}-\boldsymbol{\mu}_{i}\right\Vert ^{2} \  \  \  \ (1)$$
#
# </center>
#
#
# donde  $S$  es el conjunto de datos cuyos elementos son los objetos  $x_j$  representados por vectores, donde cada uno de sus elementos representa una característica o atributo. Tendremos  $k$  grupos o clusters con su correspondiente centroide  $μ_i$ .
#
# En cada actualización de los centroides, desde el punto de vista matemático, imponemos la condición necesaria de extremo a la función  $E(μ_i)$  que, para la función cuadrática  (1)  es
#
#
# <center>
#
# ### $$\frac{\partial E}{\partial\boldsymbol{\mu}_{i}}=0\;\Longrightarrow\;\boldsymbol{\mu}_{i}^{(t+1)}=\frac{1}{\left|S_{i}^{(t)}\right|}\sum_{\mathbf{x}_{j}\in S_{i}^{(t)}}\mathbf{x}_{j}$$
#
# </center>
#
#
#
# y se toma el promedio de los elementos de cada grupo como nuevo centroide.
#
#
#
# <img src="https://miro.medium.com/max/670/1*JUm9BrH21dEiGpHg76AImw.gif"  width="800" height="600">

# %% [markdown]
# Para entender de manera clara el algoritmo anterior,
#
#
# ### **1.  Seleccionar el número de k grupos**
#
# <img src="https://i0.wp.com/www.jacobsoft.com.mx/wp-content/uploads/2018/10/1_seleccionar_k.png?w=914&ssl=1"  width="400" height="400">

# %% [markdown]
# ### **2. Seleccionar aleatoriamente k puntos que llamaremos centroides (k = 2)**
#
# <img src="https://i0.wp.com/www.jacobsoft.com.mx/wp-content/uploads/2018/10/2_centroides.png?w=548&ssl=1">

# %% [markdown]
# ### **3. Asignar cada elemento del conjunto de datos al centroide más cercano para formar k = 2 grupos**
#
# <img src="https://i0.wp.com/www.jacobsoft.com.mx/wp-content/uploads/2018/10/3_distancias.png?w=566&ssl=1">
#
#
# <img src=" https://i0.wp.com/www.jacobsoft.com.mx/wp-content/uploads/2018/10/3_estan_asignados.png?w=556&ssl=1" >

# %% [markdown]
# ### **4. Reasignar la posición de cada centroide**
#
# <img src="https://i0.wp.com/www.jacobsoft.com.mx/wp-content/uploads/2018/10/4_reubicar.png?w=719&ssl=1">

# %% [markdown]
# ### **5. Reasignar los elementos de datos al centroide más cercano nuevamente**
#
# <img src="https://i0.wp.com/www.jacobsoft.com.mx/wp-content/uploads/2018/10/5_reasignar.png?w=674&ssl=1" width="400">

# %% [markdown]
# <img src="https://i0.wp.com/www.jacobsoft.com.mx/wp-content/uploads/2018/10/5_1_regresamos_4.png?w=723&ssl=1" width="400">

# %% [markdown]
# <img src="https://i0.wp.com/www.jacobsoft.com.mx/wp-content/uploads/2018/10/5_nuevamente_cambiamos.png?w=690&ssl=1" width="400">

# %% [markdown]
# <img src="https://i0.wp.com/www.jacobsoft.com.mx/wp-content/uploads/2018/10/7_ultima_asignacion.png?w=686&ssl=1" width=400>

# %% [markdown]
# <img src="https://i0.wp.com/www.jacobsoft.com.mx/wp-content/uploads/2018/10/8_fin.png?w=896&ssl=1" width=400>

# %% [markdown]
# <img src="https://i0.wp.com/www.jacobsoft.com.mx/wp-content/uploads/2018/10/9_sin_centroides.png?w=800&ssl=1" width="400">

# %% [markdown]
# **Nota:**  En general este método tiene la convergencia garantizada en un número pequeño de pasos.

# %% [markdown]
# Ahora vamos a crear datos hipotéticos para ver como trabaja este método. A continuación se crean 5 grupos de puntos distribuidos aleatoriamente. Para esto se utiliza la función `make_blobs`

# %%
from sklearn.datasets import make_blobs

# Se inicializan los centros
blob_centers = np.array([[ 0.2,  2.3],
                         [-1.5 ,  2.3],
                         [-2.8,  1.8],
                         [-2.8,  2.8],
                         [-2.8,  1.3]])

# Con la siguiente desviación estándar
blob_std = np.array([0.4, 0.3, 0.1, 0.1, 0.1])

# Se crean los grupos
X, y = make_blobs(n_samples=2000, centers=blob_centers,
                  cluster_std=blob_std, random_state=7)

# Se define la función para representarlos en el plano
def plot_clusters(X):
    plt.scatter(X[:, 0], X[:, 1], c=y, s=3)
    plt.xlabel("$x_1$", fontsize=14)
    plt.ylabel("$x_2$", fontsize=14, rotation=0)

# %%
import seaborn as sns
sns.set_theme()
# Se grafica
plt.figure(figsize=(10, 6))
plt.scatter(blob_centers[:,0], blob_centers[:,1], s=100, marker="s", c="g")
plot_clusters(X)
plt.show()

# %% [markdown]
# Ahora importamos la función `KMeans` del paquete `sklearn`
#
# Recuerde consultar la guia https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html para conocer mas sobre la función

# %%
X.shape
# Out:
# (2000, 2)

# %%
from sklearn.cluster import KMeans

# Paso 1: Creación del modelo
k = 5
modelo_km = KMeans(n_clusters=k, random_state=42)

# Paso 2: Ajuste
modelo_km.fit(X)

# Paso 3: Pronóstico
y_pred = modelo_km.predict(X)

print(f"Los centroides son:\n  {modelo_km.cluster_centers_}")

print('\nLas etiquetas pronósticadas son:\n', modelo_km.labels_)

X_new = np.array([[0, 2], [3, 2], [-3, 3], [-3, 2.5]])
print('\nLos pronósticos de nuevas entradas son:\n', modelo_km.predict(X_new))
# Out:
# Los centroides son:
#   [[-2.80389616  1.80117999]
#  [ 0.20876306  2.25551336]
#  [-2.79290307  2.79641063]
#  [-1.46679593  2.28585348]
#  [-2.80037642  1.30082566]]
#
# Las etiquetas pronósticadas son:
#  [4 0 1 ... 2 1 0]
#
# Los pronósticos de nuevas entradas son:
#  [1 1 2 2]

# %%
modelo_km.cluster_centers_
# Out:
# array([[-2.80389616,  1.80117999],
#        [ 0.20876306,  2.25551336],
#        [-2.79290307,  2.79641063],
#        [-1.46679593,  2.28585348],
#        [-2.80037642,  1.30082566]])

# %%
modelo_km.labels_
# Out:
# array([4, 0, 1, ..., 2, 1, 0], dtype=int32)

# %% [markdown]
# #### Ahora se crea un segundo modelo con $k=4$

# %%
## Paso 1: Definir modelo
modelo_km2 = KMeans(n_clusters=4, random_state=42)

# Paso 2: Ajustar
modelo_km2.fit(X)

print(f"los centroides son {modelo_km2.cluster_centers_}")

# Paso 3: Pronosticar
modelo_km2.predict([[-3,2], [-2,2.5]])
# Out:
# los centroides son [[-1.46679593  2.28585348]
#  [-2.80214068  1.55162671]
#  [ 0.20876306  2.25551336]
#  [-2.79290307  2.79641063]]
# array([1, 0], dtype=int32)

# %% [markdown]
# Las siguientes funciones permiten representar los clusters mediante [polígonos de Voronoi](https://https://es.wikipedia.org/wiki/Pol%C3%ADgonos_de_Thiessen). Para implementar de manera más especializada los polígonos recomiendo [esta](https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.Voronoi.html) herramienta

# %%
def plot_data(X):
    plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)

def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
        centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='o', s=30, linewidths=8,
                color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='x', s=30, linewidths=30,
                color=cross_color, zorder=11, alpha=1)

def plot_decision_boundaries(clusterer, X, resolution=1000, show_centroids=True,
                             show_xlabels=True, show_ylabels=True, title = ''):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                cmap="Pastel2")
    plt.contour(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                linewidths=1, colors='k')
    plot_data(X)
    if show_centroids:
        plot_centroids(clusterer.cluster_centers_)

    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)
    if title:
        plt.title(title)

# %%
plot_decision_boundaries(modelo_km2, X)
plt.show()

# %% [markdown]
# Mediante el siguiente comando puede encontrar la distancia entre cada instancia y su centroide

# %%
modelo_km.transform([[0,2],[1,1]])
# Out:
# array([[2.81093633, 0.32995317, 2.9042344 , 1.49439034, 2.88633901],
#        [3.88735326, 1.48403831, 4.19680888, 2.78181619, 3.81226403]])

# %% [markdown]
# ## Evaluación
#
# - Se debe tener en cuenta que diferentes incializaciones aleatorias, producirá diferentes resultados.
#
# - La mayoría de algoritmos utiliza varias incilializaciones aleatorias y selecciona el mejor resultado.
# - ¿Cómo se evalúa?. Una métrica utilizada normalmente es la *inercia*. **La inercia es la distancia cuadrática promedio de cada instancia a su centroide más cercano**. Entre menor sea la inercia mejor el modelo

# %%
modelo_km.inertia_
# Out:
# 211.59853725816828

# %%
modelo_km2.inertia_
# Out:
# 261.7967778569471

# %%
plot_decision_boundaries(modelo_km, X, title='inercia=211.6')
plt.show()
plot_decision_boundaries(modelo_km2, X, title='inercia=261.8')
plt.show()

# %% [markdown]
# ### k-means++
# Una importante mejora fue introducida en 2006. Ellos introdujeron una inicialización inteligente, de tal manera que las instancias lejanas tienen mayor probabilidad de ser centroides.
#
# ![](https://miro.medium.com/max/1662/1*JoSI7oFZXqKG8HNti0asvg.gif)

# %% [markdown]
# Otras mejoras se han realizado. En 2010 se propuso dividir la base de datos completa en mini-batches. Esto se puede implementar mediante `sklearn.cluster.MiniBatchKMeans`

# %% [markdown]
# ### Número óptimo de clusters
# El método del codo nos permite seleccionar el número óptimo de clusters mediante la inercia de diferentes modelos (cada uno con diferente número de clusters)

# %%
# Se simulan 10 modelos con diferentes k de 1 hasta 10
kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(X)
                for k in range(1, 11)]

# Se calcula la inercia de cada uno
inertias = [model.inertia_ for model in kmeans_per_k]

# Se grafican los resultados
plt.figure(figsize=(8, 3.5))
plt.plot(range(1, 11), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.annotate('Elbow',
             xy=(4, inertias[3]),
             xytext=(0.55, 0.55),
             textcoords='figure fraction',
             fontsize=16,
             arrowprops=dict(facecolor='black', shrink=0.1)
            )
plt.axis([1, 10.5, 0, 3200])
plt.show()

# %%
kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(X)
                for k in range(1, 11)]
kmeans_per_k
# Out:
# [KMeans(n_clusters=1, random_state=42),
#  KMeans(n_clusters=2, random_state=42),
#  KMeans(n_clusters=3, random_state=42),
#  KMeans(n_clusters=4, random_state=42),
#  KMeans(n_clusters=5, random_state=42),
#  KMeans(n_clusters=6, random_state=42),
#  KMeans(n_clusters=7, random_state=42),
#  KMeans(random_state=42),
#  KMeans(n_clusters=9, random_state=42),
#  KMeans(n_clusters=10, random_state=42)]

# %%
inertias = [model.inertia_ for model in kmeans_per_k]
inertias
# Out:
# [3534.8360871670734,
#  1149.6140723750264,
#  653.2167190021554,
#  261.7967778569471,
#  211.59853725816828,
#  169.237153828936,
#  141.3833648956852,
#  119.11983416102888,
#  102.59678718476387,
#  92.49741483904647]

# %% [markdown]
# Otro método es calcular la silueta. Entre más alto el valor mejor es el modelo.
#
# <center>
#
# ### $$\text{coeficiente silueta} = \dfrac{b-a}{\max(a,b)}$$
#
# </center>
#
# -  $a$ es la distancia promedio a las otras instancias del mismo cluster (media intra-cluster)
# - $b$ es la distancia promedio al cluster más cercano.
# - Varía entre $-1$ y $1$.
#
# * Si $a$ es pequeño, los puntos están muy cercanos a los centroides.
# * Si $b$ es pequeño, los clusters están muy cercanos
# * Un valor cercano a +1 significa que los puntos están bien dentro de su propio cluster y lejos de otros.
# * Un valor cercano a -1 significa que los puntos pueden estar asignados a un cluster incorrecto.
#
# **Nota**: Cada punto tiene un valor silueta
#
# ![](https://miro.medium.com/max/824/1*Piw5jgcG8Lj6FYXKkeVKmQ.png)

# %% [markdown]
# Tengo un valor de silueta alto si las galaxias están muy lejanas unas de otras (b) y las estrellas de cada galaxia están muy cerca (a). Con esto logro identificar muy bien cada galaxia.
#
# ![](https://static2.abc.es/Media/201401/08/hubble-galaxias--644x600.jpg)

# %%
from sklearn.metrics import silhouette_score
silhouette_score(X, modelo_km.labels_)
# Out:
# 0.655517642572828

# %%
silhouette_score(X, modelo_km2.labels_)
# Out:
# 0.688531617595759

# %% [markdown]
# Ahora se calcula para diferentes modelos, cada uno con diferente número de clusters.

# %%
# Calculamos el puntaje silueta por cada uno de los 10 modelos anteriores
silhouette_scores = [silhouette_score(X, model.labels_) for model in kmeans_per_k[1:]]

# Graficamos el resultado
plt.figure(figsize=(8, 3))
plt.plot(range(2, 11), silhouette_scores, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
plt.axis([1.8, 10.5, 0.55, 0.7])
plt.show()

# %% [markdown]
# Es mucho más informativo si se dibuja la silueta para cada instancia

# %%
import matplotlib as mpl
from sklearn.metrics import silhouette_samples
from matplotlib.ticker import FixedLocator, FixedFormatter

plt.figure(figsize=(11, 9))

for k in (3, 4, 5, 6):
    plt.subplot(2, 2, k - 2)
    
    y_pred = kmeans_per_k[k - 1].labels_
    silhouette_coefficients = silhouette_samples(X, y_pred)

    padding = len(X) // 30
    pos = padding
    ticks = []
    for i in range(k):
        coeffs = silhouette_coefficients[y_pred == i]
        coeffs.sort()

        color = mpl.cm.Spectral(i / k)
        plt.fill_betweenx(np.arange(pos, pos + len(coeffs)), 0, coeffs,
                          facecolor=color, edgecolor=color, alpha=0.7)
        ticks.append(pos + len(coeffs) // 2)
        pos += len(coeffs) + padding

    plt.gca().yaxis.set_major_locator(FixedLocator(ticks))
    plt.gca().yaxis.set_major_formatter(FixedFormatter(range(k)))
    if k in (3, 5):
        plt.ylabel("Cluster")
    
    if k in (5, 6):
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        plt.xlabel("Silhouette Coefficient")
    else:
        plt.tick_params(labelbottom=False)

    plt.axvline(x=silhouette_scores[k - 2], color="red", linestyle="--")
    plt.title("$k={}$".format(k), fontsize=16)

plt.show()

# %% [markdown]
# Las líneas verticales es la silueta promedio de cada modelo. Cuando la mayoría de instancias tienen un coeficiente de silueta más bajo que este, el modelo es malo. De acuerdo al resultado anterior, el modelo con 4 y 5 clusters son los mejores

# %% [markdown]
# ### Segmentación de imágenes
# Observemos esta aplicación

# %%
from matplotlib.image import imread
import urllib
import os

# Download the ladybug image
images_path = os.path.join('/')
os.makedirs(images_path, exist_ok=True)
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
filename = "ladybug.png"
print("Downloading", filename)
url = DOWNLOAD_ROOT + "images/unsupervised_learning/" + filename
urllib.request.urlretrieve(url, os.path.join(images_path, filename))

image = imread(os.path.join(images_path, filename))
image.shape
# Out:
# ...
# (533, 800, 3)

# %%
X = image.reshape(-1, 3) # Convierte la matriz de dimensiones (533x800)x3 a (426400)x3
kmeans = KMeans(n_clusters=8, random_state=42).fit(X)
segmented_img = kmeans.cluster_centers_[kmeans.labels_]
segmented_img = segmented_img.reshape(image.shape)

# %%
segmented_imgs = []
n_colors = (10, 8, 6, 4, 2)
for n_clusters in n_colors:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42).fit(X) # se crean 5 modelos y se ajustan
    segmented_img = kmeans.cluster_centers_[kmeans.labels_]
    segmented_imgs.append(segmented_img.reshape(image.shape))

# %%
plt.figure(figsize=(10,5))
plt.subplots_adjust(wspace=0.05, hspace=0.1)

plt.subplot(231)
plt.imshow(image)
plt.title("Original image")
plt.axis('off')

for idx, n_clusters in enumerate(n_colors):
    plt.subplot(232 + idx)
    plt.imshow(segmented_imgs[idx])
    plt.title("{} colors".format(n_clusters))
    plt.axis('off')

plt.show()

# %% [markdown]
# ### Límites de k-means
# Este método tiene algunas limitaciones, por ejemplo observe en seguida:
#
# ![](https://qph.fs.quoracdn.net/main-qimg-8179f95f9d2927d03bbbdeec584e4c1f)

# %% [markdown]
# ## DBSCAN
#
# Este algoritmo define los clústeres como regiones continuas de alta densidad. Así es como funciona:
#
# 1. Para cada instancia, el algoritmo cuenta cuántas instancias son
# ubicado a una pequeña distancia ε (épsilon) de él. Esta región es
# llamado vecindario ε de la instancia.
#
# 2. Si una instancia tiene al menos min_samples instancias en su vecindario ε (incluyéndose a sí misma), entonces se considera una instancia central. En otras palabras, las instancias centrales son aquellas que se ubican
# en regiones densas.
#
# 3. Todas las instancias cercanas a una instancia principal pertenecen al mismo clúster. Este vecindario puede incluir otras instancias centrales; por lo tanto, una secuencia larga de instancias centrales vecinas forma un solo clúster.
#
# 4. Cualquier instancia que no sea una instancia central y no tenga una en su vecindario se considera una anomalía
#
# ![](https://miro.medium.com/proxy/1*tc8UF-h0nQqUfLC8-0uInQ.gif)

# %% [markdown]
# Note que algunos valores dan -1, estos son considerados anomalías para el modelo

# %%
np.unique(dbscan.labels_)
# Out:
# array([-1,  0,  1,  2,  3,  4,  5,  6])

# %%
dbscan2 = DBSCAN(eps=0.2)
dbscan2.fit(X)
# Out:
# DBSCAN(eps=0.2)

# %% [markdown]
# ### El hiper-parámetro epsilon
#
# Comparemos dos modelos con diferente epsilon

# %%
def plot_dbscan(dbscan, X, size, show_xlabels=True, show_ylabels=True):
    core_mask = np.zeros_like(dbscan.labels_, dtype=bool)
    core_mask[dbscan.core_sample_indices_] = True
    anomalies_mask = dbscan.labels_ == -1
    non_core_mask = ~(core_mask | anomalies_mask)

    cores = dbscan.components_
    anomalies = X[anomalies_mask]
    non_cores = X[non_core_mask]
    
    plt.scatter(cores[:, 0], cores[:, 1],
                c=dbscan.labels_[core_mask], marker='o', s=size, cmap="Paired")
    plt.scatter(cores[:, 0], cores[:, 1], marker='*', s=20, c=dbscan.labels_[core_mask])
    plt.scatter(anomalies[:, 0], anomalies[:, 1],
                c="r", marker="x", s=100)
    plt.scatter(non_cores[:, 0], non_cores[:, 1], c=dbscan.labels_[non_core_mask], marker=".")
    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)
    plt.title("eps={:.2f}, min_samples={}".format(dbscan.eps, dbscan.min_samples), fontsize=14)

# %%
plt.figure(figsize=(9, 3.2))

plt.subplot(121)
plot_dbscan(dbscan, X, size=100)

plt.subplot(122)
plot_dbscan(dbscan2, X, size=600, show_ylabels=False)

plt.show()

# %% [markdown]
# **Otro problema del kmeans**
#
# En la imagen de abajo funciona bien k-means
#
# ![](https://miro.medium.com/max/479/1*Zl8_vxkkqv-ZV3IWZdRCmw.png)
#
# Pero en esta otra imagen, kmeans no consigue buen resultado:
#
# ![](https://miro.medium.com/max/479/1*D2nunNrckTdV9n7gTUC4Zg.png)
#
# Observe que sucede cuando aplicamos Mezcla Gaussiana:
#
# ![](https://miro.medium.com/max/479/1*eTAFs5cTUjb_kt-4RgE3uw.png)

# %% [markdown]
# ## Mezcla Gaussiana
#
# Este método asume que cada instancia fue generada por una mezcla de distribuciones gaussianas.
#
# ![](https://miro.medium.com/max/1200/1*lTv7e4Cdlp738X_WFZyZHA.png)
#
# Veamos algunos ejemplos con diferente número de gaussianas:
#
# ![](https://lh3.googleusercontent.com/proxy/nwuNYki915GX5qZg5XzfZDPe-goep4kBsGYMuI1o28lbhyJNpJFDCDD5zgs1YI6rMi9ZdW2j6PuATdy7j_tJ_6QqbfhgPFQd18i2YA48oIcIBkLqz2wvrwUMimuGnWj77-Il90s)

# %%
X1, y1 = make_blobs(n_samples=1000, centers=((4, -4), (0, 0)), random_state=42)
X1 = X1.dot(np.array([[0.374, 0.95], [0.732, 0.598]]))
X2, y2 = make_blobs(n_samples=250, centers=1, random_state=42)
X2 = X2 + [6, -8]
X = np.r_[X1, X2]
y = np.r_[y1, y2]

# %%
from sklearn.mixture import GaussianMixture

gm = GaussianMixture(n_components=3, n_init=10, random_state=42)
gm.fit(X)
# Out:
# GaussianMixture(n_components=3, n_init=10, random_state=42)

# %%
gm.weights_
# Out:
# array([0.39025715, 0.40007391, 0.20966893])

# %%
gm.means_
# Out:
# array([[ 0.05131611,  0.07521837],
#        [-1.40763156,  1.42708225],
#        [ 3.39893794,  1.05928897]])

# %%
gm.covariances_
# Out:
# array([[[ 0.68799922,  0.79606357],
#         [ 0.79606357,  1.21236106]],
#
#        [[ 0.63479409,  0.72970799],
#         [ 0.72970799,  1.1610351 ]],
#
#        [[ 1.14833585, -0.03256179],
#         [-0.03256179,  0.95490931]]])

# %%
gm.predict(X)
# Out:
# array([0, 0, 1, ..., 2, 2, 2])

# %%
X_new, y_new = gm.sample(6)
X_new
# Out:
# array([[-0.86944074, -0.32767626],
#        [ 0.29836051,  0.28297011],
#        [-2.8014927 , -0.09047309],
#        [ 3.98203732,  1.49951491],
#        [ 3.81677148,  0.53095244],
#        [ 2.84104923, -0.73858639]])

# %%
y_new
# Out:
# array([0, 0, 1, 2, 2, 2])

# %%
from matplotlib.colors import LogNorm

def plot_gaussian_mixture(clusterer, X, resolution=1000, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = -clusterer.score_samples(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z,
                 norm=LogNorm(vmin=1.0, vmax=30.0),
                 levels=np.logspace(0, 2, 12))
    plt.contour(xx, yy, Z,
                norm=LogNorm(vmin=1.0, vmax=30.0),
                levels=np.logspace(0, 2, 12),
                linewidths=1, colors='k')

    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contour(xx, yy, Z,
                linewidths=2, colors='r', linestyles='dashed')
    
    plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)
    plot_centroids(clusterer.means_, clusterer.weights_)

    plt.xlabel("$x_1$", fontsize=14)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)

# %%
plt.figure(figsize=(8, 4))
  
plot_gaussian_mixture(gm, X)

plt.show()

# %% [markdown]
# ## Notas importantes
#
# 1. Antes de hacer un modelo no supervisado es importante reducir la dimensionalidad. Por ejemplo usando reducción por componentes principales (PCA) (asociación lineal), [t-distributed Stochastic Neighbor Embedding (t-SNE)](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html), Autoencoders
#
# 2. Considere usar k-means en primera medida e intente mejorar los resultados con mezclas gaussianas utilizando las métricas de evaluación (silueta, inercia).
#
# 3. Si su interés es encontrar datos atípicos o anómalos, considere utilizar DBScan, dado que este método se especializa en encontrar puntos que están por fuera de la masa de puntos. También es muy útil en geométricas complejas (como las lunas), pero en la práctica no es habitual.

# %% [markdown]
# ## Lecturas adicionales
#
# * [Mini curso aprendizaje no supervisado Google](https://developers.google.com/machine-learning/clustering)
# * [Interpretando clusters](https://towardsdatascience.com/interpreting-clusters-29975099eea1)
# * [Cuando deberíamos usar aprendizaje no supervisado](https://www.explorium.ai/blog/clustering-when-you-should-use-it-and-avoid-it/)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6b01f3fd-002a-43ad-8b2f-83f22b9a4ee6' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
